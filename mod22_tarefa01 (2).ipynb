# %% [markdown]
# # Tarefa 01
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os monitores
# - Divirta-se :)

# %% [markdown]
# #### 1. Baixando dados de ativos
#     1. Baixe os dados de três ativos da sua escolha do Yahoo Finance, correspondente a um período de pelo menos 2 anos até a data mais recente.
#     2. Salve esses dados para que você possa utilizá-los na próxima tarefa.

# %%
from pandas_datareader import data as pdr

import plotly.express as px
from plotly import graph_objects
import yfinance as yf
yf.pdr_override()

import datetime as dt
import pandas as pd
import numpy as np

# %%
# %%time

start_date = dt.datetime(2019, 1, 1)
end_date = dt.datetime(2023, 12, 31)

yf = pdr.get_data_yahoo(['MSFT', 'DIS', 'AAPL'], start=start_date, end=end_date)
yf.head()
# Out:
# [*********************100%%**********************]  3 of 3 completed
# CPU times: user 146 ms, sys: 6.1 ms, total: 152 ms
# Wall time: 167 ms
# Price       Adj Close                             Close              \
# Ticker           AAPL         DIS       MSFT       AAPL         DIS
# Date
# 2019-01-02  37.793785  107.304626  95.673447  39.480000  108.970001
# 2019-01-03  34.029243  104.704964  92.153816  35.547501  106.330002
# 2019-01-04  35.481922  107.934837  96.439835  37.064999  109.610001
# 2019-01-07  35.402950  108.870316  96.562820  36.982498  110.559998
# 2019-01-08  36.077839  109.717171  97.262970  37.687500  111.419998
#
# Price                        High                                Low  \
# Ticker            MSFT       AAPL         DIS        MSFT       AAPL
# Date
# 2019-01-02  101.120003  39.712502  109.139999  101.750000  38.557499
# 2019-01-03   97.400002  36.430000  108.650002  100.190002  35.500000
# 2019-01-04  101.930000  37.137501  110.750000  102.510002  35.950001
# 2019-01-07  102.059998  37.207500  111.400002  103.269997  36.474998
# 2019-01-08  102.800003  37.955002  112.559998  103.970001  37.130001
#
# Price                                    Open                          \
# Ticker             DIS        MSFT       AAPL         DIS        MSFT
# Date
# 2019-01-02  107.730003   98.940002  38.722500  108.099998   99.550003
# 2019-01-03  105.940002   97.199997  35.994999  108.480003  100.099998
# 2019-01-04  107.250000   98.930000  36.132500  107.940002   99.720001
# 2019-01-07  109.300003  100.980003  37.174999  109.910004  101.639999
# 2019-01-08  111.169998  101.709999  37.389999  111.800003  103.040001
#
# Price          Volume
# Ticker           AAPL       DIS      MSFT
# Date
# 2019-01-02  148158800   9723500  35329300
# 2019-01-03  365248800  10594700  42579100
# 2019-01-04  234428400  10122800  44060600
# 2019-01-07  219111200   6714700  35656100
# 2019-01-08  164101200   8730700  31514400

# %%
yf.to_csv('dadosLimpos.csv', sep=',')

# %%
yf.shape
# Out:
# (1258, 18)

# %% [markdown]
# #### 2. Observando a volatilidade dentro do dia
# 1. Calcule a amplitude de variação do valor do ativo dentro do dia. Essa amplitude você pode calcular com um comando simples de adicionar uma coluna no Pandas: (valor máximo - valor mínimo).
# 2. Monte um gráfico de linha mostrando a variação dessa amplitude ao longo do período coletado, por ativo.
# 3. Veja se consegue identificar que ativo apresentou maior volatilidade.

# %%
amplitudade = yf['High'] - yf['Low']
amplitudade
# Out:
# Ticker          AAPL       DIS      MSFT
# Date
# 2019-01-02  1.155003  1.409996  2.809998
# 2019-01-03  0.930000  2.709999  2.990005
# 2019-01-04  1.187500  3.500000  3.580002
# 2019-01-07  0.732502  2.099998  2.289993
# 2019-01-08  0.825001  1.389999  2.260002
# ...              ...       ...       ...
# 2023-12-22  2.440002  1.489998  2.470001
# 2023-12-26  1.059998  0.669998  3.440002
# 2023-12-27  2.410004  0.900002  2.250000
# 2023-12-28  1.490005  1.010002  2.299988
# 2023-12-29  2.669998  0.739998  3.679993
#
# [1258 rows x 3 columns]

# %%
amplitudade_v = yf['Adj Close'].stack().reset_index()
amplitudade_v.columns = ['data', 'ativo', 'valor']

amplitudade_v.head()
# Out:
#         data ativo       valor
# 0 2019-01-02  AAPL   37.793785
# 1 2019-01-02   DIS  107.304626
# 2 2019-01-02  MSFT   95.673447
# 3 2019-01-03  AAPL   34.029243
# 4 2019-01-03   DIS  104.704964

# %%
fig = px.line(amplitudade_v, x='data', y='valor', color='ativo', template='ggplot2')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b81d6c80-faf8-4f0f-8627-2a1696b3c6b8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b81d6c80-faf8-4f0f-8627-2a1696b3c6b8")) {                    Plotly.newPlot(                        "b81d6c80-faf8-4f0f-8627-2a1696b3c6b8",                        [{"hovertemplate":"ativo=AAPL\u003cbr\u003edata=%{x}\u003cbr\u003evalor=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"AAPL","line":{"color":"#F8766D","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"AAPL","showlegend":true,"x":["2019-01-02T00:00:00","2019-01-03T00:00:00","2019-01-04T00:00:00","2019-01-07T00:00:00","2019-01-08T00:00:00","2019-01-09T00:00:00","2019-01-10T00:00:00","2019-01-11T00:00:00","2019-01-14T00:00:00","2019-01-15T00:00:00","2019-01-16T00:00:00","2019-01-17T00:00:00","2019-01-18T00:00:00","2019-01-22T00:00:00","2019-01-23T00:00:00","2019-01-24T00:00:00","2019-01-25T00:00:00","2019-01-28T00:00:00","2019-01-29T00:00:00","2019-01-30T00:00:00","2019-01-31T00:00:00","2019-02-01T00:00:00","2019-02-04T00:00:00","2019-02-05T00:00:00","2019-02-06T00:00:00","2019-02-07T00:00:00","2019-02-08T00:00:00","2019-02-11T00:00:00","2019-02-12T00:00:00","2019-02-13T00:00:00","2019-02-14T00:00:00","2019-02-15T00:00:00","2019-02-19T00:00:00","2019-02-20T00:00:00","2019-02-21T00:00:00","2019-02-22T00:00:00","2019-02-25T00:00:00","2019-02-26T00:00:00","2019-02-27T00:00:00","2019-02-28T00:00:00","2019-03-01T00:00:00","2019-03-04T00:00:00","2019-03-05T00:00:00","2019-03-06T00:00:00","2019-03-07T00:00:00","2019-03-08T00:00:00","2019-03-11T00:00:00","2019-03-12T00:00:00","2019-03-13T00:00:00","2019-03-14T00:00:00","2019-03-15T00:00:00","2019-03-18T00:00:00","2019-03-19T00:00:00","2019-03-20T00:00:00","2019-03-21T00:00:00","2019-03-22T00:00:00","2019-03-25T00:00:00","2019-03-26T00:00:00","2019-03-27T00:00:00","2019-03-28T00:00:00","2019-03-29T00:00:00","2019-04-01T00:00:00","2019-04-02T00:00:00","2019-04-03T00:00:00","2019-04-04T00:00:00","2019-04-05T00:00:00","2019-04-08T00:00:00","2019-04-09T00:00:00","2019-04-10T00:00:00","2019-04-11T00:00:00","2019-04-12T00:00:00","2019-04-15T00:00:00","2019-04-16T00:00:00","2019-04-17T00:00:00","2019-04-18T00:00:00","2019-04-22T00:00:00","2019-04-23T00:00:00","2019-04-24T00:00:00","2019-04-25T00:00:00","2019-04-26T00:00:00","2019-04-29T00:00:00","2019-04-30T00:00:00","2019-05-01T00:00:00","2019-05-02T00:00:00","2019-05-03T00:00:00","2019-05-06T00:00:00","2019-05-07T00:00:00","2019-05-08T00:00:00","2019-05-09T00:00:00","2019-05-10T00:00:00","2019-05-13T00:00:00","2019-05-14T00:00:00","2019-05-15T00:00:00","2019-05-16T00:00:00","2019-05-17T00:00:00","2019-05-20T00:00:00","2019-05-21T00:00:00","2019-05-22T00:00:00","2019-05-23T00:00:00","2019-05-24T00:00:00","2019-05-28T00:00:00","2019-05-29T00:00:00","2019-05-30T00:00:00","2019-05-31T00:00:00","2019-06-03T00:00:00","2019-06-04T00:00:00","2019-06-05T00:00:00","2019-06-06T00:00:00","2019-06-07T00:00:00","2019-06-10T00:00:00","2019-06-11T00:00:00","2019-06-12T00:00:00","2019-06-13T00:00:00","2019-06-14T00:00:00","2019-06-17T00:00:00","2019-06-18T00:00:00","2019-06-19T00:00:00","2019-06-20T00:00:00","2019-06-21T00:00:00","2019-06-24T00:00:00","2019-06-25T00:00:00","2019-06-26T00:00:00","2019-06-27T00:00:00","2019-06-28T00:00:00","2019-07-01T00:00:00","2019-07-02T00:00:00","2019-07-03T00:00:00","2019-07-05T00:00:00","2019-07-08T00:00:00","2019-07-09T00:00:00","2019-07-10T00:00:00","2019-07-11T00:00:00","2019-07-12T00:00:00","2019-07-15T00:00:00","2019-07-16T00:00:00","2019-07-17T00:00:00","2019-07-18T00:00:00","2019-07-19T00:00:00","2019-07-22T00:00:00","2019-07-23T00:00:00","2019-07-24T00:00:00","2019-07-25T00:00:00","2019-07-26T00:00:00","2019-07-29T00:00:00","2019-0 ...

# %% [markdown]
# O ativo que apresentou maior volatividade foi o MSFT
